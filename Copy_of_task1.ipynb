# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanyagowd/PRODIGY_DS_01/blob/main/Copy_of_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRODIGY INFOTECH
# DONE BY : DHANYASHREE.S
#
# email id:dhanyagowda170@gmail.com

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import io

# %%
from google.colab import files
newFiles=files.upload()
# Out:
#      <input type="file" id="files-6b938404-771e-4a10-b882-0f8819d8ba0e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b938404-771e-4a10-b882-0f8819d8ba0e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('pop1.csv.csv')
df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
tol_pop=df[df['Indicator Code']=='SP.POP.TOTL']
tol_pop.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %%
pop_sort=tol_pop.sort_values(by='2022',ascending=False)
pop_sort
# Out:
#                Country Name Country Code     Indicator Name Indicator Code  \
# 259                   World          WLD  Population, total    SP.POP.TOTL
# 103        IDA & IBRD total          IBT  Population, total    SP.POP.TOTL
# 140     Low & middle income          LMY  Population, total    SP.POP.TOTL
# 156           Middle income          MIC  Population, total    SP.POP.TOTL
# 102               IBRD only          IBD  Population, total    SP.POP.TOTL
# ..                      ...          ...                ...            ...
# 255  British Virgin Islands          VGB  Population, total    SP.POP.TOTL
# 188                   Palau          PLW  Population, total    SP.POP.TOTL
# 179                   Nauru          NRU  Population, total    SP.POP.TOTL
# 245                  Tuvalu          TUV  Population, total    SP.POP.TOTL
# 110          Not classified          INX  Population, total    SP.POP.TOTL
#
# ...

# %%
highest_pop=pop_sort.head(5)
print("Top 5 countries with the highest populaion in 2022")
highest_pop
# Out:
# Top 5 countries with the highest populaion in 2022
#             Country Name Country Code     Indicator Name Indicator Code  \
# 259                World          WLD  Population, total    SP.POP.TOTL
# 103     IDA & IBRD total          IBT  Population, total    SP.POP.TOTL
# 140  Low & middle income          LMY  Population, total    SP.POP.TOTL
# 156        Middle income          MIC  Population, total    SP.POP.TOTL
# 102            IBRD only          IBD  Population, total    SP.POP.TOTL
#
#              1960          1961          1962          1963          1964  \
# 259  3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
# 103  2.297972e+09  2.329504e+09  2.374276e+09  2.431314e+09  2.488809e+09
# 140  2.243179e+09  2.274050e+09  2.318173e+09  2.374537e+09  2.431355e+09
# 156  2.107416e+09  2.135116e+09  2.175940e+09  2.228877e+09  2.282094e+09
# 102  1.904347e+09  1.926043e+09  1.960606e+09  2.007061e+09  2.053555e+09
#
# ...

# %%
highest_pop=pop_sort.head(10)
print("Top 10 countries with the highest populaion in 2022")
highest_pop
# Out:
# Top 10 countries with the highest populaion in 2022
#                    Country Name Country Code     Indicator Name  \
# 259                       World          WLD  Population, total
# 103            IDA & IBRD total          IBT  Population, total
# 140         Low & middle income          LMY  Population, total
# 156               Middle income          MIC  Population, total
# 102                   IBRD only          IBD  Population, total
# 62   Early-demographic dividend          EAR  Population, total
# 139         Lower middle income          LMC  Population, total
# 249         Upper middle income          UMC  Population, total
# 63          East Asia & Pacific          EAS  Population, total
# 142   Late-demographic dividend          LTE  Population, total
#
#     Indicator Code          1960          1961          1962          1963  \
# 259    SP.POP.TOTL  3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09
# ...

# %% [markdown]
# #  **DATA VISUALIZATION**
#
# ---

# %%
def add_value_labels(ax,spacing=10):
  for rect in ax.patches:
    x=rect.get_x()+rect.get_width()/2
    y=rect.get_height()-3

    va='bottom' if y>0 else 'top'
    label='()'.format(y)
    y_shift=spacing*(1 if y>=0 else -1)
    ax.annotate(label,(x,y),xytext=(0,y_shift),textcoords='offset points', ha='center',va=va)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
plt.rcParams['axes.facecolor'] = 'black'

plt.subplot(2,2,1)
plot = sns.barplot(x="2022", y="Country Name", data=highest_pop, palette="viridis", color='green')
plt.title("Top 10 countries Of Total Population (2022)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot = sns.barplot(x="2000", y="Country Name", data=highest_pop, palette="viridis", color='blue')
plt.title("Top Ten countries of Total Population in 2000")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-3c4d1efcd11c>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.barplot(x="2022", y="Country Name", data=highest_pop, palette="viridis", color='green')
# <ipython-input-22-3c4d1efcd11c>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.barplot(x="2000", y="Country Name", data=highest_pop, palette="viridis", color='blue')

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(20,15))
plt.rcParams['axes.facecolor'] = "black"  # Use "=" instead of "=="

plt.subplot(2,2,1)
plot = sns.scatterplot(x='2022', y="Country Name", data=highest_pop, palette="coolwarm")
plt.title("Top Ten countries Of Total Population 2022")
plt.xlabel("Total population")
plt.ylabel("country")
# Assuming you have a function add_value_labels() defined somewhere
# add_value_labels(plot)

plt.subplot(2,2,2)
plot = sns.scatterplot(x='2000', y="Country Name", data=highest_pop, palette="coolwarm")
plt.title("Top countries Of Total Population 2000")
plt.xlabel("Total population")
plt.ylabel("country")
# Assuming you have a function add_value_labels() defined somewhere
# add_value_labels(plot)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-23-b38115bfcf3f>:9: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   plot = sns.scatterplot(x='2022', y="Country Name", data=highest_pop, palette="coolwarm")
# <ipython-input-23-b38115bfcf3f>:17: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   plot = sns.scatterplot(x='2000', y="Country Name", data=highest_pop, palette="coolwarm")

# %%
total_population_sort_bt=tol_pop.sort_values(by='2022',ascending=True)
total_population_sort_bt
# Out:
#                  Country Name Country Code     Indicator Name Indicator Code  \
# 245                    Tuvalu          TUV  Population, total    SP.POP.TOTL
# 179                     Nauru          NRU  Population, total    SP.POP.TOTL
# 188                     Palau          PLW  Population, total    SP.POP.TOTL
# 255    British Virgin Islands          VGB  Population, total    SP.POP.TOTL
# 147  St. Martin (French part)          MAF  Population, total    SP.POP.TOTL
# ..                        ...          ...                ...            ...
# 156             Middle income          MIC  Population, total    SP.POP.TOTL
# 140       Low & middle income          LMY  Population, total    SP.POP.TOTL
# 103          IDA & IBRD total          IBT  Population, total    SP.POP.TOTL
# 259                     World          WLD  Population, total    SP.POP.TOTL
# 110            Not classified          INX  Population, total    SP.POP.TOTL
#
# ...

# %%
top_ten_bt_countries=total_population_sort_bt.head(10)
print("Top ten bottom Countries of Total Population:")
print(top_ten_bt_countries)
# Out:
# Top ten bottom Countries of Total Population:
#                  Country Name Country Code     Indicator Name Indicator Code  \
# 245                    Tuvalu          TUV  Population, total    SP.POP.TOTL
# 179                     Nauru          NRU  Population, total    SP.POP.TOTL
# 188                     Palau          PLW  Population, total    SP.POP.TOTL
# 255    British Virgin Islands          VGB  Population, total    SP.POP.TOTL
# 147  St. Martin (French part)          MAF  Population, total    SP.POP.TOTL
# 84                  Gibraltar          GIB  Population, total    SP.POP.TOTL
# 212                San Marino          SMR  Population, total    SP.POP.TOTL
# 149                    Monaco          MCO  Population, total    SP.POP.TOTL
# 137             Liechtenstein          LIE  Population, total    SP.POP.TOTL
# 155          Marshall Islands          MHL  Population, total    SP.POP.TOTL
#
#         1960     1961     1962     1963     1964     1965  ...     2013  \
# ...

# %%
plt.figure(figsize=(20,15))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.scatterplot(x='2022',y="Country Name", data=top_ten_bt_countries, palette="coolwarm")
plt.title("Bottom Ten countries Of Total Population 2022")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.scatterplot(x='2000',y="Country Name", data=top_ten_bt_countries,palette="coolwarm")
plt.title("Bottom countries Of Total Population 2000")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
# Out:
# <ipython-input-40-260e4a11839b>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   plot=sns.scatterplot(x='2022',y="Country Name", data=top_ten_bt_countries, palette="coolwarm")
# <ipython-input-40-260e4a11839b>:12: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   plot=sns.scatterplot(x='2000',y="Country Name", data=top_ten_bt_countries,palette="coolwarm")
